# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import json
import random
import csv
import secrets
import string
import bcrypt
import base64
import uuid
import binascii

# %%
#get the data from vehicle json
data_vehicle = open('vehiclev3.json' , 'r')
data1 = json.load(data_vehicle)

        

notificationList = []
newN= {
      "fault_name": "Charging System Malfunction",
      "description": "There is a malfunction in the vehicle's charging system, impacting charging efficiency and battery health.",
      "timestamp":"2023-03-22T10:44:27.528Z",
      "obdii_params": [
        {
          "param_name": "Charging Voltage",
          "value" :13.5, 
          "pid": "S1_PID_07",
          "description": "Voltage level during charging"
            
        },
        {
          "param_name": "AvailableChargePower",
          "value" :30.5 , 
          "pid": "S1_PID_08",
          "description": "Available power for charging the electric vehicle battery"
        }
      ]
    }
notificationList.append(newN)

newN={
      "fault_name": "Electric Vehicle Range Estimation Error",
      "description": "The vehicle's range estimation system is reporting inaccurate or inconsistent range predictions.",
      "timestamp":"2023-03-22T10:44:27.528Z",
      "obdii_params": [
        {
          "param_name": "BatteryMaxTemperature",
          "value" :10.6, 
          "pid": "S1_PID_01",
          "description": "Maximum temperature of the electric vehicle battery"
        },
        {
          "param_name": "BatteryMinTemperature",
          "value" :123.7, 
          "pid": "S1_PID_02",
          "description": "Minimum temperature of the electric vehicle battery"
        },
        {
          "param_name": "BatteryModule8Temperature",
          "value" :-12.6, 
          "pid": "S1_PID_03",
          "description": "Temperature of the 8th module in the electric vehicle battery"
        },
        {
          "param_name": "BatteryCellVoltageDeviation",
          "value" :500.2, 
          "pid": "S1_PID_04",
          "description": "Voltage deviation among individual cells in the electric vehicle battery"
        }
      ]
    }

notificationList.append(newN)


#let's add the notification to the vehicle as well 

for vehicle in data1: 
    if(vehicle['vehicleInfo']['vin'] == "5YJ3E1EA1M"):
        vehicle['notificationList'] = notificationList
    
    
    
    
#add the notification to new collection called Notifications
file_path = "vv4.json"
#save the new data to new json file 
with open(file_path, 'w') as f:
    json.dump(data1, f)

# %%
newL= [
    {
      "fault_name": "Electric Vehicle Range Estimation Error",
      "description": "The vehicle's range estimation system is reporting inaccurate or inconsistent range predictions.",
      "obdii_params": [
        {
          "param_name": "BatteryMaxTemperature",
          "pid": "S1_PID_01",
           "thresholdValue": random.randint(-70, 20),
          "description": "Maximum temperature of the electric vehicle battery"
        },
        {
          "param_name": "BatteryMinTemperature",
          "pid": "S1_PID_02",
          "thresholdValue": random.randint(-70, 20),
          "description": "Minimum temperature of the electric vehicle battery"
        },
        {
          "param_name": "BatteryModule8Temperature",
          "pid": "S1_PID_03",
          "thresholdValue": random.randint(-70, 20),
          "description": "Temperature of the 8th module in the electric vehicle battery"
        },
        {
          "param_name": "BatteryCellVoltageDeviation",
          "pid": "S1_PID_04",
          "thresholdValue": random.randint(-70, 20),
          "description": "Voltage deviation among individual cells in the electric vehicle battery"
        }
      ]
    },
    {
      "fault_name": "Battery State of Health (SOH) Degradation",
      "description": "The battery's state of health is degrading, leading to reduced driving range and performance.",
      "obdii_params": [
        {
          "param_name": "BatteryMaxTemperature",
          "pid": "S1_PID_01",
          "thresholdValue": random.randint(-70, 20),
          "description": "Maximum temperature of the electric vehicle battery"
        },
        {
          "param_name": "BatteryModule6Temperature",
          "pid": "S1_PID_05",
          "thresholdValue": random.randint(-70, 20),
          "description": "Temperature of the 6th module in the electric vehicle battery"
        },
        {
          "param_name": "BatteryCellVoltageDeviation",
          "pid": "S1_PID_04",
          "thresholdValue": random.randint(-70, 20),
          "description": "Voltage deviation among individual cells in the electric vehicle battery"
        }
      ]
    },
    {
      "fault_name": "Electric Motor Overheating",
      "description": "The electric motor is overheating, potentially due to prolonged high power demand or cooling system issues.",
      "obdii_params": [
        {
          "param_name": "Electric Motor Temperature",
          "pid": "S1_PID_06",
            "thresholdValue": random.randint(-70, 20),
          "description": "Temperature of the electric motor"
        },
        {
          "param_name": "BatteryMaxTemperature",
          "pid": "S1_PID_01",
            "thresholdValue": random.randint(-70, 20),
          "description": "Maximum temperature of the electric vehicle battery"
        }
      ]
    },
    {
      "fault_name": "Charging System Malfunction",
      "description": "There is a malfunction in the vehicle's charging system, impacting charging efficiency and battery health.",
      "obdii_params": [
        {
          "param_name": "Charging Voltage",
          "pid": "S1_PID_07",
            "thresholdValue": random.randint(-70, 20),
          "description": "Voltage level during charging"
        },
        {
          "param_name": "AvailableChargePower",
          "pid": "S1_PID_08",
            "thresholdValue": random.randint(-70, 20),
          "description": "Available power for charging the electric vehicle battery"
        }
      ]
    },
    {
      "fault_name": "Battery Cell Imbalance",
      "description": "There is a significant imbalance in the voltages of individual battery cells, affecting overall battery performance.",
      "obdii_params": [
        {
          "param_name": "BatteryCellVoltageDeviation",
          "pid": "S1_PID_04",
            "thresholdValue": random.randint(-70, 20),
          "description": "Voltage deviation among individual cells in the electric vehicle battery"
        }
      ]
    },
    {
      "fault_name": "High-Voltage System Insulation Deterioration",
      "description": "The high-voltage system's insulation is deteriorating, posing potential safety risks.",
      "obdii_params": [
        {
          "param_name": "High-Voltage Bus Voltage",
          "pid": "S1_PID_09",
            "thresholdValue": random.randint(-70, 20),
          "description": "Voltage level of the high-voltage bus"
        },
        {
          "param_name": "High-Voltage Leakage Current",
          "pid": "S1_PID_10",
            "thresholdValue": random.randint(-70, 20),
          "description": "Leakage current in the high-voltage system"
        }
      ]
    },
    {
      "fault_name": "Brake Regenerative System Fault",
      "description": "The brake regenerative system is not operating correctly, reducing energy recapture during braking.",
      "obdii_params": [
        {
          "param_name": "Regenerative Brake Current",
          "pid": "S1_PID_11",
            "thresholdValue": random.randint(-70, 20),
          "description": "Electric current flowing through the regenerative braking system"
        },
        {
          "param_name": "Regenerative Brake Torque",
          "pid": "S1_PID_12",
            "thresholdValue": random.randint(-70, 20),
          "description": "Torque generated by the regenerative braking system"
        }
      ]
    },
    {
      "fault_name": "Tire Pressure Monitoring System (TPMS) Error",
      "description": "The TPMS is reporting errors or inconsistencies with tire pressure readings.",
      "obdii_params": [
        {
          "param_name": "Tire Pressure Front Left",
          "pid": "S1_PID_13",
            "thresholdValue": random.randint(-70, 20),
          "description": "Pressure reading from the front left tire"
        },
        {
          "param_name": "Tire Pressure Front Right",
          "pid": "S1_PID_14",
            "thresholdValue": random.randint(-70, 20),
          "description": "Pressure reading from the front right tire"
        }
      ]
    },
    {
      "fault_name": "Electric Power Steering (EPS) Calibration Issue",
      "description": "There is a calibration issue with the electric power steering system, affecting steering performance.",
      "obdii_params": [
        {
          "param_name": "Steering Angle Sensor",
          "pid": "S1_PID_15",
            "thresholdValue": random.randint(-70, 20),
          "description": "Angle of the steering wheel"
        },
        {
          "param_name": "EPS Motor Current",
          "pid": "S1_PID_16",
            "thresholdValue": random.randint(-70, 20),
          "description": "Electric current flowing through the EPS motor"
        }
      ]
    },
    {
      "fault_name": "DC Fast Charging Malfunction",
      "description": "The DC fast charging system is not functioning correctly, impacting charging speed and reliability.",
      "obdii_params": [
        {
          "param_name": "DC Charging Voltage",
          "pid": "S1_PID_17",
            "thresholdValue": random.randint(-70, 20),
          "description": "Voltage level during DC fast charging"
        },
        {
          "param_name": "DC Charging Current",
          "pid": "S1_PID_18",
            "thresholdValue": random.randint(-70, 20),
          "description": "Electric current during DC fast charging"
        }
      ]
    },
    {
      "fault_name": "Motor Controller Communication Error",
      "description": "There is a communication error between the motor controller and other vehicle systems.",
      "obdii_params": [
        {
          "param_name": "Motor Controller Temperature",
          "pid": "S1_PID_19",
            "thresholdValue": random.randint(-70, 20),
          "description": "Temperature of the electric motor controller"
        },
        {
          "param_name": "Motor Controller Voltage",
          "pid": "S1_PID_20",
            "thresholdValue": random.randint(-70, 20),
          "description": "Voltage level of the motor controller"
        }
      ]
    },
    {
      "fault_name": "Battery Heater Malfunction",
      "description": "The battery heater is not functioning correctly, leading to reduced performance in cold weather.",
      "obdii_params": [
        {
          "param_name": "BatteryHeaterTemp1",
          "pid": "S1_PID_21",
            "thresholdValue": random.randint(-70, 20),
          "description": "Temperature of the first battery heater in the electric vehicle"
        },
        {
          "param_name": "BatteryHeaterTemp2",
          "pid": "S1_PID_22",
            "thresholdValue": random.randint(-70, 20),
          "description": "Temperature of the second battery heater in the electric vehicle"
        }
      ]
    },
    {
      "fault_name": "Motor Overcurrent",
      "description": "The electric motor is experiencing overcurrent conditions, potentially due to high load or electrical issues.",
      "obdii_params": [
        {
          "param_name": "Electric Motor Current",
          "pid": "S1_PID_23",
            "thresholdValue": random.randint(-70, 20),
          "description": "Electric current flowing through the electric motor"
        }
      ]
    },
    {
      "fault_name": "Electric Vehicle Inverter Fault",
      "description": "The inverter, responsible for converting DC to AC power, is malfunctioning, impacting motor performance.",
      "obdii_params": [
        {
          "param_name": "Inverter Temperature",
          "pid": "S1_PID_24",
            "thresholdValue": random.randint(-70, 20),
          "description": "Temperature of the electric vehicle inverter"
        }
      ]
    },
    {
      "fault_name": "HVAC System Performance Drop",
      "description": "The HVAC system's performance is declining, impacting cabin comfort and energy efficiency.",
      "obdii_params": [
        {
          "param_name": "HVAC Compressor Speed",
          "pid": "S1_PID_25",
            "thresholdValue": random.randint(-70, 20),
          "description": "Speed of the HVAC compressor"
        }
      ]
    },
    {
      "fault_name": "Battery State of Charge (SOC) Calibration Error",
      "description": "There is a calibration error in the battery's state of charge (SOC) estimation, affecting range prediction accuracy.",
      "obdii_params": [
        {
          "param_name": "State of Charge (SOC)",
          "pid": "S1_PID_26",
            "thresholdValue": random.randint(-70, 20),
          "description": "Percentage of charge remaining in the vehicle battery"
        }
      ]
    },
    {
      "fault_name": "HVAC Blower Malfunction",
      "description": "The HVAC blower is not functioning correctly, impacting the distribution of air within the vehicle cabin.",
      "obdii_params": [
        {
          "param_name": "HVAC Blower Speed",
          "pid": "S1_PID_27",
            "thresholdValue": random.randint(-70, 20),
          "description": "HVAC blower speed setting"
        }
      ]
    },
    {
      "fault_name": "Battery Module Communication Error",
      "description": "There is a communication error between battery modules, affecting data exchange and performance.",
      "obdii_params": [
        {
          "param_name": "BatteryModule6Temperature",
          "pid": "S1_PID_28",
            "thresholdValue": random.randint(-70, 20),
          "description": "Temperature of the 6th module in the electric vehicle battery"
        }
      ]
    },
    {
      "fault_name": "Battery Cooling System Fault",
      "description": "The battery cooling system is not functioning correctly, leading to overheating of the battery.",
      "obdii_params": [
        {
          "param_name": "BatteryMaxTemperature",
          "pid": "S1_PID_01",
            "thresholdValue": random.randint(-70, 20),
          "description": "Maximum temperature of the electric vehicle battery"
        }
      ]
    }
  ]
    


#add the notification to new collection called Notifications
file_path = "notification.json"
#save the new data to new json file 
with open(file_path, 'w') as f:
    json.dump(newL, f)
